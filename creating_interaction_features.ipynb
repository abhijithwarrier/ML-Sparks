# %% [markdown]
# **Programmer:** python_scripts (Abhijith Warrier)
#
# **PYTHON SCRIPT TO _CREATE INTERACTION FEATURES TO IMPROVE MODEL PERFORMANCE ON TABULAR DATA_. ⚡️🔗📊**
#
# This script demonstrates how to create **interaction features**, which combine two or more existing features to capture relationships that a model might otherwise miss.

# %% [markdown]
# ---

# %% [markdown]
# ## **📦 Import Required Libraries**

# %%
import pandas as pd

from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %% [markdown]
# ---

# %% [markdown]
# ## **🧩 Load Dataset**

# %%
data = fetch_california_housing()

X = pd.DataFrame(data.data, columns=data.feature_names)
y = data.target

# %% [markdown]
# ---

# %% [markdown]
# ## **✂️ Split Data**

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=42
)

# %% [markdown]
# ---

# %% [markdown]
# ## **🚨 Baseline Model (No Interaction Features)**

# %%
baseline_model = LinearRegression()
baseline_model.fit(X_train, y_train)

baseline_pred = baseline_model.predict(X_test)

print("Baseline R2 Score:", r2_score(y_test, baseline_pred))
# Out:
# Baseline R2 Score: 0.5957702326061658

# %% [markdown]
# ---

# %% [markdown]
# ## **🔗 Create Interaction Features**
#
# We create new features by multiplying existing ones.

# %%
X_train_interact = X_train.copy()
X_test_interact = X_test.copy()

# Correct interaction features for California dataset
X_train_interact["MedInc_HouseAge"] = X_train["MedInc"] * X_train["HouseAge"]
X_test_interact["MedInc_HouseAge"] = X_test["MedInc"] * X_test["HouseAge"]

X_train_interact["AveRooms_Population"] = X_train["AveRooms"] * X_train["Population"]
X_test_interact["AveRooms_Population"] = X_test["AveRooms"] * X_test["Population"]

# %% [markdown]
# These features capture relationships between variables.

# %% [markdown]
# ---

# %% [markdown]
# ## **🤖 Train Model with Interaction Features**

# %%
interaction_model = LinearRegression()
interaction_model.fit(X_train_interact, y_train)

interaction_pred = interaction_model.predict(X_test_interact)

print("With Interaction Features R2 Score:", r2_score(y_test, interaction_pred))
# Out:
# With Interaction Features R2 Score: 0.5972658300880964

# %% [markdown]
# ---

# %% [markdown]
# ## **🔍 Why Interaction Features Matter**
#
# Some relationships in data are not linear:
#
# - feature A alone → weak signal
# - feature B alone → weak signal
# - A × B → strong signal
#
# Interaction features help models capture such hidden patterns.

# %% [markdown]
# ---

# %% [markdown]
# ## **🧠 Key Takeaways**
#
# 1. Interaction features combine multiple variables.
# 2. They help capture non-linear relationships.
# 3. Simple models like Linear Regression benefit greatly.
# 4. Feature engineering can improve performance without changing the model.
# 5. A powerful and practical technique in real-world ML.

# %% [markdown]
# ---

# %% [markdown]
# ## **Conclusion**
#
# Creating interaction features is a simple yet effective way to improve model performance, especially for tabular data. By combining existing features, we can uncover hidden patterns and enhance predictive power without switching to more complex models.
#
# This introduces **Feature Engineering** into the **Saturday ML Spark ⚡️ series**, moving beyond models into data-driven improvements.

# %% [markdown]
# ---
